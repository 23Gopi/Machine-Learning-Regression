# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_linear.sav", 'rb')) #RB Means Read Binary
user_input=int(input("Enter Your experience"))
result = loaded_model.predict([[user_input]])
result
# Out:
# Enter Your experience13
# array([[148460.78806172]])
