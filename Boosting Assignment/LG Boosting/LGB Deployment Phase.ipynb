# %%
import pickle

# %%
filename="LGBoosting_final_model.sav"
loaded_model=pickle.load(open(filename,'rb'))
age_input=float(input("Age:"))
bmi_input=float(input("BMI"))
childer_input=float(input("Chilrend "))
gender_input=int(input("Enter the Gender 0 or 1"))
new_input=int(input("Enter smoker 0 or 1:"))
# Out:
# Age: 30
# BMI 95
# Chilrend  2
# Enter the Gender 0 or 1 1
# Enter smoker 0 or 1: 1

# %%
result=loaded_model.predict([[age_input,bmi_input,childer_input,gender_input,new_input]])
result
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# array([42648.10090519])
